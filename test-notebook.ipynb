# %%
import spert
from transformers import AdamW, BertConfig

data = [{"tokens": ["Due", "to", "the", "black-box", "nature", "of", "deep", "learning", "models", ",", "methods", "for", "explaining", "the", "models\u2019", "results", "are", "crucial", "to", "gain", "trust", "from", "humans", "and", "support", "collaboration", "between", "AIs", "and", "humans", ".", "In", "this", "paper", ",", "we", "consider", "several", "model-agnostic", "and", "model-specific", "explanation", "methods", "for", "CNNs", "for", "text", "classification", "and", "conduct", "three", "human-grounded", "evaluations", ",", "focusing", "on", "different", "purposes", "of", "explanations", ":", "(", "1", ")", "revealing", "model", "behavior", ",", "(", "2", ")", "justifying", "model", "predictions", ",", "and", "(", "3", ")", "helping", "humans", "investigate", "uncertain", "predictions", ".", "The", "results", "highlight", "dissimilar", "qualities", "of", "the", "various", "explanation", "methods", "we", "consider", "and", "show", "the", "degree", "to", "which", "these", "methods", "could", "serve", "for", "each", "purpose", "."]}]

spert.predict(data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import spert
#       2 from transformers import AdamW, BertConfig
#       4 data = [{"tokens": ["Due", "to", "the", "black-box", "nature", "of", "deep", "learning", "models", ",", "methods", "for", "explaining", "the", "models\u2019", "results", "are", "crucial", "to", "gain", "trust", "from", "humans", "and", "support", "collaboration", "between", "AIs", "and", "humans", ".", "In", "this", "paper", ",", "we", "consider", "several", "model-agnostic", "and", "model-specific", "explanation", "methods", "for", "CNNs", "for", "text", "classification", "and", "conduct", "three", "human-grounded", "evaluations", ",", "focusing", "on", "different", "purposes", "of", "explanations", ":", "(", "1", ")", "revealing", "model", "behavior", ",", "(", "2", ")", "justifying", "model", "predictions", ",", "and", "(", "3", ")", "helping", "humans", "investigate", "uncertain", "predictions", ".", "The", "results", "highlight", "dissimilar", "qualities", "of", "the", "various", "explanation", "methods", "we", "consider", "and", "show", "the", "degree", "to", "which", "these", "methods", "could", "serve", "for", "each", "purpose", "."]}]
#
# File /workspaces/SpERT-adaptation/SpERT/spert/__init__.py:1
# ----> 1 from .spert import *
#
# File /workspaces/SpERT-adaptation/SpERT/spert/spert.py:8
#       6 from .config_reader import process_configs
#       7 from .src import input_reader
# ----> 8 from .src.spert_trainer import SpERTTrainer
#      11 def __train(run_args):
#      12     trainer = SpERTTrainer(run_args)
#
# File /workspaces/SpERT-adaptation/SpERT/spert/src/spert_trainer.py:10
#       8 import transformers
#       9 from torch.utils.data import DataLoader
# ---> 10 from transformers import AdamW, BertConfig
#      11 from transformers import BertTokenizer
#      13 from . import models
#
# ImportError: cannot import name 'AdamW' from 'transformers' (/home/codespace/.python/current/lib/python3.12/site-packages/transformers/__init__.py)
